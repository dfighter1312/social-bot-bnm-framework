# %%
import pandas as pd
import numpy as np

# %%
cols = ['text']

df_bot = pd.concat(
    [
        pd.read_csv('../data/set-2/tweets/social_spambots_1.csv', nrows=50000),
        pd.read_csv('../data/set-2/tweets/social_spambots_2.csv', nrows=50000),
        pd.read_csv('../data/set-2/tweets/social_spambots_3.csv', nrows=50000)
    ]
).reset_index(drop=True)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_naive = pd.read_csv('../data/set-2/tweets/tweets.csv', header=None, escapechar='\\', nrows=150000)

# %% [markdown]
# Since the number of rows is extremely large, you may want to limit the number of tweets to a specified one. It can be done by explicitly declare `nrows=10000` (for example) in the `pd.read_csv` function.

# %% [markdown]
# ### Bot data information

# %%
df_bot.shape
# Out:
# (150000, 25)

# %%
df_bot.head()
# Out:
#                    id                                               text  \
# 0  532627591686275072   I Pooh - In silenzio 1968 http://t.co/ahvQxUqTws
# 1  532624255058706432                             http://t.co/HyI5EQKz6Q
# 2  532513524460052480  Tutti a tavola, con il filetto di baccalà. htt...
# 3  532297646669852672                             http://t.co/NAHQ4l2pUy
# 4  532295960807100416       Gold - Spandau Ballet http://t.co/o8ZJHt7Neu
#
#                                               source   user_id  truncated  \
# 0  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 1  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 2  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 3  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 4  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
#
#    in_reply_to_status_id  in_reply_to_user_id in_reply_to_screen_name  \
# ...

# %%
df_bot.describe()
# Out:
#                  id       user_id  truncated  in_reply_to_status_id  \
# count  1.500000e+05  1.500000e+05        0.0           1.500000e+05
# mean   4.626108e+17  2.967768e+08        NaN           5.787088e+16
# std    9.657295e+16  5.607741e+08        NaN           1.584129e+17
# min    1.341215e+09  1.619534e+07        NaN           0.000000e+00
# 25%    4.485701e+17  2.992261e+07        NaN           0.000000e+00
# 50%    4.991980e+17  1.099058e+08        NaN           0.000000e+00
# 75%    5.223976e+17  2.371976e+08        NaN           0.000000e+00
# max    5.326649e+17  2.236860e+09        NaN           5.326558e+17
#
#        in_reply_to_user_id  retweeted_status_id  geo  contributors  \
# count         1.500000e+05         1.500000e+05  0.0           0.0
# mean          1.061614e+08         2.788205e+16  NaN           NaN
# std           4.280027e+08         1.117094e+17  NaN           NaN
# min           0.000000e+00         0.000000e+00  NaN           NaN
# ...

# %%
df_bot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       150000 non-null  int64
#  1   text                     149662 non-null  object
#  2   source                   150000 non-null  object
#  3   user_id                  150000 non-null  int64
#  4   truncated                0 non-null       float64
#  5   in_reply_to_status_id    150000 non-null  int64
#  6   in_reply_to_user_id      150000 non-null  int64
#  7   in_reply_to_screen_name  20171 non-null   object
#  8   retweeted_status_id      150000 non-null  int64
#  9   geo                      0 non-null       float64
#  10  place                    3817 non-null    object
#  11  contributors             0 non-null       float64
#  12  retweet_count            150000 non-null  int64
# ...

# %%
df_bot.apply(lambda x: x.unique())
# Out:
# id                         [532627591686275072, 532624255058706432, 53251...
# text                       [I Pooh - In silenzio 1968 http://t.co/ahvQxUq...
# source                     [<a href="http://www.facebook.com/twitter" rel...
# user_id                    [24858289, 33212890, 39773427, 57007623, 63258...
# truncated                                                              [nan]
# in_reply_to_status_id      [0, 513435006312935424, 487526737254027264, 43...
# in_reply_to_user_id        [0, 24858289, 194167741, 35880562, 46079849, 1...
# in_reply_to_screen_name    [nan, davideb66, TIM119Stefano, diegosolimena,...
# retweeted_status_id        [0, 513611877386301440, 419456288632758273, 21...
# geo                                                                    [nan]
# place                      [nan, Chioggia, Venezia, Campo San Martino, Pa...
# contributors                                                           [nan]
# ...

# %% [markdown]
# ### Naive data information

# %%
df_naive.shape
# Out:
# (150000, 26)

# %%
df_naive.head()
# Out:
#                    0                                                  1   \
# 0  593932392663912449  RT @morningJewshow: Speaking about Jews and co...
# 1  593895316719423488  This age/face recognition thing..no reason pla...
# 2  593880638069018624  Only upside of the moment I can think of is th...
# 3  593847955536252928  If you're going to think about+create experien...
# 4  593847687847350272  Watching a thread on FB about possible future ...
#
#                                                   2       3   4   5   6    7   \
# 0  <a href="http://tapbots.com/tweetbot" rel="nof...  678033 NaN   0   0  NaN
# 1  <a href="http://twitter.com" rel="nofollow">Tw...  678033 NaN   0   0  NaN
# 2  <a href="http://twitter.com" rel="nofollow">Tw...  678033 NaN   0   0  NaN
# 3  <a href="http://tapbots.com/tweetbot" rel="nof...  678033 NaN   0   0  NaN
# 4  <a href="http://tapbots.com/tweetbot" rel="nof...  678033 NaN   0   0  NaN
#
#                    8  9   ...  16  17  18  19  20  21  \
# ...

# %%
df_naive.describe()
# Out:
#                  0             3    4             5             6   \
# count  1.500000e+05  1.500000e+05  0.0  1.500000e+05  1.500000e+05
# mean   5.197325e+17  3.560442e+08  NaN  1.629534e+17  1.784614e+08
# std    9.014934e+16  5.589239e+08  NaN  2.476952e+17  5.280001e+08
# min    6.460111e+06  6.780330e+05  NaN  0.000000e+00  0.000000e+00
# 25%    4.898536e+17  3.888491e+06  NaN  0.000000e+00  0.000000e+00
# 50%    5.543094e+17  1.490382e+08  NaN  0.000000e+00  0.000000e+00
# 75%    5.803455e+17  4.815058e+08  NaN  4.707296e+17  2.554573e+07
# max    5.940943e+17  1.676580e+09  NaN  5.940906e+17  3.202361e+09
#
#                  8    12            13        14             15   16   17  \
# count  1.500000e+05  0.0  1.500000e+05  150000.0  150000.000000  0.0  0.0
# mean   1.386008e+17  NaN  6.085401e+02       0.0       0.436373  NaN  NaN
# std    2.363257e+17  NaN  1.264981e+04       0.0       2.007949  NaN  NaN
# ...

# %%
df_naive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 26 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       150000 non-null  int64
#  1   1       149449 non-null  object
#  2   2       149987 non-null  object
#  3   3       150000 non-null  int64
#  4   4       0 non-null       float64
#  5   5       150000 non-null  int64
#  6   6       150000 non-null  int64
#  7   7       50056 non-null   object
#  8   8       150000 non-null  int64
#  9   9       150000 non-null  object
#  10  10      150000 non-null  object
#  11  11      15065 non-null   object
#  12  12      0 non-null       float64
#  13  13      150000 non-null  int64
#  14  14      150000 non-null  int64
#  15  15      150000 non-null  int64
#  16  16      0 non-null       float64
#  17  17      0 non-null       float64
#  18  18      108634 non-null  object
#  19  19      150000 non-null  int64
# ...

# %%
df_naive.drop(12, axis=1, inplace=True)
df_naive.columns = df_bot.columns

# %%
df_naive.apply(lambda x: x.unique())
# Out:
# id                         [593932392663912449, 593895316719423488, 59388...
# text                       [RT @morningJewshow: Speaking about Jews and c...
# source                     [<a href="http://tapbots.com/tweetbot" rel="no...
# user_id                    [678033, 722623, 755116, 755746, 785080, 80658...
# truncated                                                              [nan]
# in_reply_to_status_id      [0, 593641901539995648, 593649065847427072, 59...
# in_reply_to_user_id        [0, 143569237, 19119809, 14249445, 20479813, 2...
# in_reply_to_screen_name    [nan, thelancearthur, wkamaubell, frogtosser, ...
# retweeted_status_id        [593932168524533760, 0, 593808590269353984, 59...
# geo                        [N, 32.37840507, 32.37747677, 32.35779893, 32....
# place                      [N, -111.08425711, -111.08541519, -111.0914323...
# contributors               [nan, Tucson, AZ, Casas Adobes, AZ, Marana, AZ...
# ...

# %% [markdown]
# The missing values contain not only `nan` but also `N` (there is also `0` in `in_reply_to_status_id`, `in_reply_to_user_id` and `in_reply_to_screen_name`, so you should carefully replace this while dealing with missing values.
