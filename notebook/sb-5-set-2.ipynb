# %%
import numpy as np
import pandas as pd
import re
import tensorflow as tf

from sklearn.model_selection import train_test_split

# %%
df_bot = pd.concat(
    [
        pd.read_csv('../data/set-2/tweets/social_spambots_1.csv', nrows=10000),
        pd.read_csv('../data/set-2/tweets/social_spambots_2.csv', nrows=10000),
        pd.read_csv('../data/set-2/tweets/social_spambots_3.csv', nrows=10000)
    ]
).reset_index(drop=True)

# %%
df_naive = pd.read_csv('../data/set-2/tweets/tweets.csv', header=None, escapechar='\\', nrows=30000)

# %%
df_naive.drop(12, axis=1, inplace=True)
df_naive.columns = df_bot.columns

# %%
df = pd.concat([df_bot, df_naive], ignore_index=True)
label = y = np.concatenate(
    [
        np.zeros((df_bot.shape[0],)),
        np.ones((df_naive.shape[0],))
    ]
)
df.head()
# Out:
#                    id                                               text  \
# 0  532627591686275072   I Pooh - In silenzio 1968 http://t.co/ahvQxUqTws
# 1  532624255058706432                             http://t.co/HyI5EQKz6Q
# 2  532513524460052480  Tutti a tavola, con il filetto di baccalà. htt...
# 3  532297646669852672                             http://t.co/NAHQ4l2pUy
# 4  532295960807100416       Gold - Spandau Ballet http://t.co/o8ZJHt7Neu
#
#                                               source   user_id  truncated  \
# 0  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 1  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 2  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 3  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
# 4  <a href="http://www.facebook.com/twitter" rel=...  24858289        NaN
#
#    in_reply_to_status_id  in_reply_to_user_id in_reply_to_screen_name  \
# 0                      0                    0                     NaN
# 1                      0                    0                     NaN
# 2                      0                    0                     NaN
# 3                      0                    0                     NaN
# 4                      0                    0                     NaN
#
#    retweeted_status_id  geo  ... favorited retweeted  possibly_sensitive  \
# 0                    0  NaN  ...       NaN       NaN                 NaN
# 1                    0  NaN  ...       NaN       NaN                 NaN
# 2                    0  NaN  ...       NaN       NaN                 NaN
# 3                    0  NaN  ...       NaN       NaN                 NaN
# 4                    0  NaN  ...       NaN       NaN                 NaN
#
#    num_hashtags  num_urls  num_mentions                      created_at  \
# 0             0         1             0  Wed Nov 12 20:14:48 +0000 2014
# 1             0         1             0  Wed Nov 12 20:01:32 +0000 2014
# 2             0         1             0  Wed Nov 12 12:41:32 +0000 2014
# 3             0         1             0  Tue Nov 11 22:23:43 +0000 2014
# 4             0         1             0  Tue Nov 11 22:17:01 +0000 2014
#
#              timestamp           crawled_at              updated
# 0  2014-11-12 21:14:48  2014-11-12 21:44:09  2014-11-12 21:44:09
# 1  2014-11-12 21:01:32  2014-11-12 21:44:09  2014-11-12 21:44:09
# 2  2014-11-12 13:41:32  2014-11-12 21:44:09  2014-11-12 21:44:09
# 3  2014-11-11 23:23:43  2014-11-12 21:44:09  2014-11-12 21:44:09
# 4  2014-11-11 23:17:01  2014-11-12 21:44:09  2014-11-12 21:44:09
#
# [5 rows x 25 columns]

# %% [markdown]
# # Preprocessing

# %%
URL_PATTERN = "^((http[s]?|ftp):\/)?\/?([^:\/\s]+)((\/\w+)*\/)([\w\-\.]+[^#?\s]+)(.*)?(#[\w\-]+)?$"

def isAllCaps(word):
    for c in word:
        if c.islower() or not c.isalpha():
            return False
    return True

def hasRepeatedLetters(word):
    prev = ''
    prev2 = ''
    for c in word:
        if c == prev:
            if c == prev2:
                return True
        prev2 = prev
        prev = c
    return False

# In the paper, the tags will be denote as <hashtag>, for example
# but for convenience for the nltk's word_tokenizer, we will change
# the <tag> to tagtag (<url> -> urltag)
def text_tags(row):
    rowlist = str(row).split()
    rowlist = [word.strip() for word in rowlist]
    rowlist = [word if not word.strip().startswith(
        '#') else "hashtagtag" for word in rowlist]
    rowlist = [word if not word.strip().startswith(
        '@') else "usertag" for word in rowlist]
    rowlist = [word if not isAllCaps(
        word.strip()) else word.lower() + " allcapstag" for word in rowlist]
    rowlist = [word if not hasRepeatedLetters(
        word.strip()) else word + " repeatedtag" for word in rowlist]
    rowlist = [word.lower() for word in rowlist]
    rowlist = [re.sub(URL_PATTERN, "urltag", word) for word in rowlist]
    return " ".join(rowlist)

# %%
df["text_processed"] = df["text"].apply(text_tags)
df["text_processed"][:5]
# Out:
# 0          i allcapstag pooh - in silenzio 1968 urltag
# 1                                               urltag
# 2    tutti a tavola, con il filetto di baccalà. urltag
# 3                                               urltag
# 4                         gold - spandau ballet urltag
# Name: text_processed, dtype: object

# %% [markdown]
# # Glove Embeddings + LSTM

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df["text_processed"].values,
    y,
    test_size=0.2,
    random_state=0
)

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=5000)

tokenizer.fit_on_texts(X_train)
words_to_index = tokenizer.word_index

# %%
def read_glove_vector(glove_vec):
    with open(glove_vec, 'r', encoding='UTF-8') as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            w_line = line.split()
            curr_word = w_line[0]
            word_to_vec_map[curr_word] = np.array(w_line[1:], dtype=np.float64)
    return word_to_vec_map

# %%
word_to_vec_map = read_glove_vector('../glove/glove.twitter.27B.50d.txt')

# %%
maxLen = 200
embed_vector_len = 50
vocab_len = len(words_to_index)

emb_matrix = np.zeros((vocab_len, embed_vector_len))

for word, index in words_to_index.items():
    embedding_vector = word_to_vec_map.get(word)
    if embedding_vector is not None:
        emb_matrix[index-1, :] = embedding_vector

embedding_layer = tf.keras.layers.Embedding(
    input_dim=vocab_len,
    output_dim=embed_vector_len,
    input_length=maxLen,
    weights = [emb_matrix],
    trainable=False
)

# %%
def lstm_glove_model(input_shape):
    X_indices = tf.keras.Input(input_shape)
    embeddings = embedding_layer(X_indices)
    lstm = tf.keras.layers.LSTM(32, return_sequences=True)(embeddings)
    dense_1 = tf.keras.layers.Dense(16)(lstm)
    dense_2 = tf.keras.layers.Dense(8)(dense_1)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(dense_2)
    
    model = tf.keras.Model(inputs=X_indices, outputs=output)
    
    return model

# %%
X_train_indices = tokenizer.texts_to_sequences(X_train)

X_train_indices = tf.keras.preprocessing.sequence.pad_sequences(X_train_indices, maxlen=maxLen, padding='post')

# %%
model = lstm_glove_model(input_shape=(maxLen,))
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train_indices, y_train, batch_size=256, epochs=50)
# Out:
# Epoch 1/50
# 188/188 [==============================] - 35s 186ms/step - loss: 0.6600 - accuracy: 0.5997
# Epoch 2/50
# 188/188 [==============================] - 33s 175ms/step - loss: 0.6010 - accuracy: 0.6783
# Epoch 3/50
# 188/188 [==============================] - 37s 195ms/step - loss: 0.5618 - accuracy: 0.7115
# Epoch 4/50
# 188/188 [==============================] - 37s 198ms/step - loss: 0.5396 - accuracy: 0.7283
# Epoch 5/50
# 188/188 [==============================] - 34s 180ms/step - loss: 0.5184 - accuracy: 0.7434
# Epoch 6/50
# 188/188 [==============================] - 34s 179ms/step - loss: 0.5073 - accuracy: 0.7517s -
# Epoch 7/50
# 188/188 [==============================] - 35s 186ms/step - loss: 0.4931 - accuracy: 0.7631
# Epoch 8/50
# 188/188 [==============================] - 39s 207ms/step - loss: 0.4852 - accuracy: 0.7688
# Epoch 9/50
# 188/188 [==============================] - 41s 219ms/step - loss: 0.4803 - accuracy: 0.7730
# Epoch 10/50
# 188/188 [==============================] - 41s 217ms/step - loss: 0.4675 - accuracy: 0.7823
# Epoch 11/50
# 188/188 [==============================] - 40s 215ms/step - loss: 0.4598 - accuracy: 0.7865
# Epoch 12/50
# 188/188 [==============================] - 34s 183ms/step - loss: 0.4532 - accuracy: 0.7905
# Epoch 13/50
# 188/188 [==============================] - 34s 181ms/step - loss: 0.4484 - accuracy: 0.7930
# Epoch 14/50
# 188/188 [==============================] - 47s 248ms/step - loss: 0.4439 - accuracy: 0.7982
# Epoch 15/50
# 188/188 [==============================] - 43s 228ms/step - loss: 0.4394 - accuracy: 0.7993
# Epoch 16/50
# 188/188 [==============================] - 34s 182ms/step - loss: 0.4372 - accuracy: 0.7999
# Epoch 17/50
# 188/188 [==============================] - 36s 190ms/step - loss: 0.4310 - accuracy: 0.8055
# Epoch 18/50
# 188/188 [==============================] - 34s 182ms/step - loss: 0.4283 - accuracy: 0.8057
# Epoch 19/50
# 188/188 [==============================] - 35s 188ms/step - loss: 0.4240 - accuracy: 0.8074
# Epoch 20/50
# 188/188 [==============================] - 35s 187ms/step - loss: 0.4180 - accuracy: 0.8127
# Epoch 21/50
# 188/188 [==============================] - 34s 180ms/step - loss: 0.4179 - accuracy: 0.8121
# Epoch 22/50
# 188/188 [==============================] - 36s 190ms/step - loss: 0.4090 - accuracy: 0.8172
# Epoch 23/50
# 188/188 [==============================] - 43s 228ms/step - loss: 0.4118 - accuracy: 0.8148
# Epoch 24/50
# 188/188 [==============================] - 38s 203ms/step - loss: 0.4052 - accuracy: 0.8181
# Epoch 25/50
# 188/188 [==============================] - 37s 195ms/step - loss: 0.4010 - accuracy: 0.8203
# Epoch 26/50
# 188/188 [==============================] - 34s 183ms/step - loss: 0.4031 - accuracy: 0.8205
# Epoch 27/50
# 188/188 [==============================] - 36s 191ms/step - loss: 0.3946 - accuracy: 0.8251
# Epoch 28/50
# 188/188 [==============================] - 35s 187ms/step - loss: 0.3952 - accuracy: 0.8248
# Epoch 29/50
# 188/188 [==============================] - 39s 206ms/step - loss: 0.3922 - accuracy: 0.8256s - los
# Epoch 30/50
# 188/188 [==============================] - 40s 214ms/step - loss: 0.3900 - accuracy: 0.8269
# Epoch 31/50
# 188/188 [==============================] - 37s 197ms/step - loss: 0.3893 - accuracy: 0.8281
# Epoch 32/50
# 188/188 [==============================] - 36s 190ms/step - loss: 0.3871 - accuracy: 0.8283
# Epoch 33/50
# 188/188 [==============================] - 35s 185ms/step - loss: 0.3885 - accuracy: 0.8292
# Epoch 34/50
# 188/188 [==============================] - 34s 183ms/step - loss: 0.3773 - accuracy: 0.8345
# Epoch 35/50
# 188/188 [==============================] - 35s 185ms/step - loss: 0.3781 - accuracy: 0.8335
# Epoch 36/50
# 188/188 [==============================] - 35s 186ms/step - loss: 0.3744 - accuracy: 0.8363
# Epoch 37/50
# 188/188 [==============================] - 35s 185ms/step - loss: 0.3745 - accuracy: 0.8363
# Epoch 38/50
# 188/188 [==============================] - 35s 189ms/step - loss: 0.3691 - accuracy: 0.8382
# Epoch 39/50
# 188/188 [==============================] - 33s 176ms/step - loss: 0.3708 - accuracy: 0.8381
# Epoch 40/50
# 188/188 [==============================] - 34s 182ms/step - loss: 0.3722 - accuracy: 0.8368
# Epoch 41/50
# 188/188 [==============================] - 34s 182ms/step - loss: 0.3674 - accuracy: 0.8404
# Epoch 42/50
# 188/188 [==============================] - 35s 188ms/step - loss: 0.3644 - accuracy: 0.8412
# Epoch 43/50
# 188/188 [==============================] - 34s 182ms/step - loss: 0.3593 - accuracy: 0.8438
# Epoch 44/50
# 188/188 [==============================] - 42s 225ms/step - loss: 0.3572 - accuracy: 0.8453
# Epoch 45/50
# 188/188 [==============================] - 42s 225ms/step - loss: 0.3587 - accuracy: 0.8440
# Epoch 46/50
# 188/188 [==============================] - 45s 238ms/step - loss: 0.3637 - accuracy: 0.8410
# Epoch 47/50
# 188/188 [==============================] - 37s 199ms/step - loss: 0.3558 - accuracy: 0.8460
# Epoch 48/50
# 188/188 [==============================] - 36s 191ms/step - loss: 0.3533 - accuracy: 0.8457
# Epoch 49/50
# 188/188 [==============================] - 37s 197ms/step - loss: 0.3495 - accuracy: 0.8491
# Epoch 50/50
# 188/188 [==============================] - 43s 231ms/step - loss: 0.3511 - accuracy: 0.8490

# %% [markdown]
# # GloVe Embeddings + Contextual LSTM

# %%
def contextual_lstm_glove_model(text_input_shape, metadata_input_shape):
    text = tf.keras.Input(text_input_shape)
    embeddings = embedding_layer(text)
    lstm = tf.keras.layers.LSTM(32, return_sequences=True)(embeddings)
    
    metadata = tf.keras.Input(metadata_input_shape)
    
    concat = tf.keras.layers.concatenate([lstm, metadata])
    
    dense_1 = tf.keras.layers.Dense(16)(concat)
    dense_2 = tf.keras.layers.Dense(8)(dense_1)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(dense_2)
    
    model = tf.keras.Model(inputs=X_indices, outputs=output)
    
    return model
