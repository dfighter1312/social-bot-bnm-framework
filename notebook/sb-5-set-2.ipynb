# %%
import numpy as np
import pandas as pd
import re
import tensorflow as tf

from sklearn.model_selection import train_test_split

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_bot = pd.concat(
    [
        pd.read_csv('gdrive/MyDrive/Thesis/Thesis Workspace/Notebooks/data/set-2/tweets/social_spambots_1.csv', nrows=20000),
        pd.read_csv('gdrive/MyDrive/Thesis/Thesis Workspace/Notebooks/data/set-2/tweets/social_spambots_2.csv', nrows=20000),
        pd.read_csv('gdrive/MyDrive/Thesis/Thesis Workspace/Notebooks/data/set-2/tweets/social_spambots_3.csv', nrows=20000)
    ]
).reset_index(drop=True)

# %%
df_naive = pd.read_csv('gdrive/MyDrive/Thesis/Thesis Workspace/Notebooks/data/set-2/tweets/tweets.csv', header=None, escapechar='\\', nrows=60000)

# %%
df_naive.drop(12, axis=1, inplace=True)
df_naive.columns = df_bot.columns

# %%
df = pd.concat([df_bot, df_naive], ignore_index=True)
label = y = np.concatenate(
    [
        np.zeros((df_bot.shape[0],)),
        np.ones((df_naive.shape[0],))
    ]
)
df.head()
# Out:
#                    id  ...              updated
# 0  532627591686275072  ...  2014-11-12 21:44:09
# 1  532624255058706432  ...  2014-11-12 21:44:09
# 2  532513524460052480  ...  2014-11-12 21:44:09
# 3  532297646669852672  ...  2014-11-12 21:44:09
# 4  532295960807100416  ...  2014-11-12 21:44:09
#
# [5 rows x 25 columns]

# %% [markdown]
# # Preprocessing

# %%
URL_PATTERN = "^((http[s]?|ftp):\/)?\/?([^:\/\s]+)((\/\w+)*\/)([\w\-\.]+[^#?\s]+)(.*)?(#[\w\-]+)?$"

def isAllCaps(word):
    for c in word:
        if c.islower() or not c.isalpha():
            return False
    return True

def hasRepeatedLetters(word):
    prev = ''
    prev2 = ''
    for c in word:
        if c == prev:
            if c == prev2:
                return True
        prev2 = prev
        prev = c
    return False

# In the paper, the tags will be denote as <hashtag>, for example
# but for convenience for the nltk's word_tokenizer, we will change
# the <tag> to tagtag (<url> -> urltag)
def text_tags(row):
    rowlist = str(row).split()
    rowlist = [word.strip() for word in rowlist]
    rowlist = [word if not word.strip().startswith(
        '#') else "hashtagtag" for word in rowlist]
    rowlist = [word if not word.strip().startswith(
        '@') else "usertag" for word in rowlist]
    rowlist = [word if not isAllCaps(
        word.strip()) else word.lower() + " allcapstag" for word in rowlist]
    rowlist = [word if not hasRepeatedLetters(
        word.strip()) else word + " repeatedtag" for word in rowlist]
    rowlist = [word.lower() for word in rowlist]
    rowlist = [re.sub(URL_PATTERN, "urltag", word) for word in rowlist]
    return " ".join(rowlist)

# %%
df["text_processed"] = df["text"].apply(text_tags)
df["text_processed"][:5]
# Out:
# 0          i allcapstag pooh - in silenzio 1968 urltag
# 1                                               urltag
# 2    tutti a tavola, con il filetto di baccalà. urltag
# 3                                               urltag
# 4                         gold - spandau ballet urltag
# Name: text_processed, dtype: object

# %%
train_idx, test_idx, y_train, y_test = train_test_split(
    np.arange(df.shape[0]),
    y,
    test_size=0.2,
    random_state=0
)
X_train = df["text_processed"][train_idx]
X_test = df["text_processed"][test_idx]

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=5000)

tokenizer.fit_on_texts(X_train)
words_to_index = tokenizer.word_index

# %% [markdown]
# # GloVe Embeddings + LSTM

# %%
def read_glove_vector(glove_vec):
    with open(glove_vec, 'r', encoding='UTF-8') as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            w_line = line.split()
            curr_word = w_line[0]
            word_to_vec_map[curr_word] = np.array(w_line[1:], dtype=np.float64)
    return word_to_vec_map

# %%
word_to_vec_map = read_glove_vector('gdrive/MyDrive/Thesis/Thesis Workspace/Notebooks/glove/glove.twitter.27B.50d.txt')

# %%
maxLen = 500
embed_vector_len = 50
vocab_len = len(words_to_index)

emb_matrix = np.zeros((vocab_len, embed_vector_len))

for word, index in words_to_index.items():
    embedding_vector = word_to_vec_map.get(word)
    if embedding_vector is not None:
        emb_matrix[index-1, :] = embedding_vector

embedding_layer = tf.keras.layers.Embedding(
    input_dim=vocab_len,
    output_dim=embed_vector_len,
    input_length=maxLen,
    weights = [emb_matrix],
    trainable=False
)

# %%
def lstm_glove_model(input_shape):
    X_indices = tf.keras.Input(input_shape)
    embeddings = embedding_layer(X_indices)
    lstm = tf.keras.layers.LSTM(32, return_sequences=True)(embeddings)
    flatten = tf.keras.layers.Flatten()(lstm)
    dense_1 = tf.keras.layers.Dense(1024)(flatten)
    dense_2 = tf.keras.layers.Dense(256)(dense_1)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(dense_2)
    
    model = tf.keras.Model(inputs=X_indices, outputs=output)
    
    return model

# %%
X_train_indices = tokenizer.texts_to_sequences(X_train)

X_train_indices = tf.keras.preprocessing.sequence.pad_sequences(X_train_indices, maxlen=maxLen, padding='post')

# %%
model = lstm_glove_model(input_shape=(maxLen,))
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
model.fit(X_train_indices, y_train, batch_size=256, epochs=50)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500)]             0
#
#  embedding (Embedding)       (None, 500, 50)           4138550
#
#  lstm (LSTM)                 (None, 500, 32)           10624
#
#  flatten (Flatten)           (None, 16000)             0
#
#  dense (Dense)               (None, 1024)              16385024
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 20,796,855
# Trainable params: 16,658,305
# Non-trainable params: 4,138,550
# _________________________________________________________________
# None
# Epoch 1/50
# 375/375 [==============================] - 42s 94ms/step - loss: 0.5889 - accuracy: 0.6691
# Epoch 2/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.5195 - accuracy: 0.7356
# Epoch 3/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4899 - accuracy: 0.7539
# Epoch 4/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4712 - accuracy: 0.7675
# Epoch 5/50
# 375/375 [==============================] - 32s 86ms/step - loss: 0.4588 - accuracy: 0.7741
# Epoch 6/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4492 - accuracy: 0.7801
# Epoch 7/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4416 - accuracy: 0.7848
# Epoch 8/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4357 - accuracy: 0.7871
# Epoch 9/50
# 375/375 [==============================] - 32s 87ms/step - loss: 0.4292 - accuracy: 0.7917
# Epoch 10/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4239 - accuracy: 0.7943
# Epoch 11/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4216 - accuracy: 0.7944
# Epoch 12/50
# 375/375 [==============================] - 32s 86ms/step - loss: 0.4155 - accuracy: 0.7992
# Epoch 13/50
# 375/375 [==============================] - 32s 87ms/step - loss: 0.4114 - accuracy: 0.8014
# Epoch 14/50
# 375/375 [==============================] - 32s 87ms/step - loss: 0.4084 - accuracy: 0.8023
# Epoch 15/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4031 - accuracy: 0.8070
# Epoch 16/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4004 - accuracy: 0.8076
# Epoch 17/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3983 - accuracy: 0.8088
# Epoch 18/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3954 - accuracy: 0.8108
# Epoch 19/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3918 - accuracy: 0.8131
# Epoch 20/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3901 - accuracy: 0.8132
# Epoch 21/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3867 - accuracy: 0.8142
# Epoch 22/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3848 - accuracy: 0.8151
# Epoch 23/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3829 - accuracy: 0.8163
# Epoch 24/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3807 - accuracy: 0.8173
# Epoch 25/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3771 - accuracy: 0.8198
# Epoch 26/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3763 - accuracy: 0.8206
# Epoch 27/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3741 - accuracy: 0.8209
# Epoch 28/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3721 - accuracy: 0.8215
# Epoch 29/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3702 - accuracy: 0.8229
# Epoch 30/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3686 - accuracy: 0.8240
# Epoch 31/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3664 - accuracy: 0.8244
# Epoch 32/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3641 - accuracy: 0.8261
# Epoch 33/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3635 - accuracy: 0.8259
# Epoch 34/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3614 - accuracy: 0.8270
# Epoch 35/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3608 - accuracy: 0.8273
# Epoch 36/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3592 - accuracy: 0.8282
# Epoch 37/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3569 - accuracy: 0.8301
# Epoch 38/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3550 - accuracy: 0.8312
# Epoch 39/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3539 - accuracy: 0.8307
# Epoch 40/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3528 - accuracy: 0.8322
# Epoch 41/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3521 - accuracy: 0.8320
# Epoch 42/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3495 - accuracy: 0.8343
# Epoch 43/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3486 - accuracy: 0.8348
# Epoch 44/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3947 - accuracy: 0.8171
# Epoch 45/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3537 - accuracy: 0.8317
# Epoch 46/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3469 - accuracy: 0.8352
# Epoch 47/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3451 - accuracy: 0.8368
# Epoch 48/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3432 - accuracy: 0.8367
# Epoch 49/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3433 - accuracy: 0.8377
# Epoch 50/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3435 - accuracy: 0.8371

# %%
X_test_indices = tokenizer.texts_to_sequences(X_test)
X_test_indices = tf.keras.preprocessing.sequence.pad_sequences(X_test_indices, maxlen=maxLen, padding='post')
model.evaluate(X_test_indices, y_test)
# Out:
# 750/750 [==============================] - 24s 31ms/step - loss: 0.4513 - accuracy: 0.7955
# [0.45125237107276917, 0.7954583168029785]

# %% [markdown]
# # GloVe Embeddings + Contextual LSTM

# %%
def contextual_lstm_glove_model(text_input_shape, metadata_input_shape):
    text = tf.keras.Input(text_input_shape)
    embeddings = embedding_layer(text)
    lstm = tf.keras.layers.LSTM(32, return_sequences=True)(embeddings)
    flatten = tf.keras.layers.Flatten()(lstm)
    
    metadata = tf.keras.Input(metadata_input_shape)
    
    concat = tf.keras.layers.concatenate([flatten, metadata], axis=1)
    
    dense_1 = tf.keras.layers.Dense(1024)(concat)
    dense_2 = tf.keras.layers.Dense(256)(dense_1)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(dense_2)
    
    model = tf.keras.Model(inputs=[text, metadata], outputs=output)
    
    return model

# %%
def get_metadata(df):
    COLUMN_NAMES = ['retweet_count', 'favorite_count',
                    'num_hashtags', 'num_urls', 'num_mentions']
    return df[COLUMN_NAMES].replace('N', np.nan).fillna(0)

# %%
df_metadata = get_metadata(df)

# %%
mean = df_metadata.mean(axis=0)
std = df_metadata.std(axis=0)

# %%
df_metadata = (df_metadata - mean) / std
df_metadata.head()
# Out:
#    retweet_count  favorite_count  num_hashtags  num_urls  num_mentions
# 0      -0.038828       -0.095142     -0.394058  1.267671     -0.703404
# 1      -0.038828       -0.095142     -0.394058  1.267671     -0.703404
# 2      -0.038828       -0.095142     -0.394058  1.267671     -0.703404
# 3      -0.038828       -0.095142     -0.394058  1.267671     -0.703404
# 4      -0.038828       -0.095142     -0.394058  1.267671     -0.703404

# %%
X_meta_train = df_metadata.iloc[train_idx].values
X_meta_test = df_metadata.iloc[test_idx].values

# %%
model = contextual_lstm_glove_model(text_input_shape=(maxLen,), metadata_input_shape=(5,))
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
model.fit([X_train_indices, X_meta_train], y_train, batch_size=256, epochs=50)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 500)]        0           []
#
#  embedding (Embedding)          (None, 500, 50)      4138550     ['input_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 500, 32)      10624       ['embedding[1][0]']
#
#  flatten_1 (Flatten)            (None, 16000)        0           ['lstm_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 5)]          0           []
#
#  concatenate (Concatenate)      (None, 16005)        0           ['flatten_1[0][0]',
#                                                                   'input_3[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         16390144    ['concatenate[0][0]']
#
#  dense_4 (Dense)                (None, 256)          262400      ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            257         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 20,801,975
# Trainable params: 16,663,425
# Non-trainable params: 4,138,550
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 375/375 [==============================] - 38s 96ms/step - loss: 1.1406 - accuracy: 0.6787
# Epoch 2/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.4928 - accuracy: 0.7647
# Epoch 3/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.4524 - accuracy: 0.7914
# Epoch 4/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4319 - accuracy: 0.8043
# Epoch 5/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4146 - accuracy: 0.8145
# Epoch 6/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.4012 - accuracy: 0.8209
# Epoch 7/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3918 - accuracy: 0.8256
# Epoch 8/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3810 - accuracy: 0.8312
# Epoch 9/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3762 - accuracy: 0.8332
# Epoch 10/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3686 - accuracy: 0.8369
# Epoch 11/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3722 - accuracy: 0.8365
# Epoch 12/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.3730 - accuracy: 0.8366
# Epoch 13/50
# 375/375 [==============================] - 33s 87ms/step - loss: 52.7283 - accuracy: 0.7670
# Epoch 14/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.5800 - accuracy: 0.7451
# Epoch 15/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.5158 - accuracy: 0.7623
# Epoch 16/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.5101 - accuracy: 0.7717
# Epoch 17/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4703 - accuracy: 0.7874
# Epoch 18/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.4494 - accuracy: 0.7964
# Epoch 19/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.4330 - accuracy: 0.8058
# Epoch 20/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.4236 - accuracy: 0.8115
# Epoch 21/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4153 - accuracy: 0.8157
# Epoch 22/50
# 375/375 [==============================] - 33s 87ms/step - loss: 0.4129 - accuracy: 0.8167
# Epoch 23/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3984 - accuracy: 0.8228
# Epoch 24/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3943 - accuracy: 0.8263
# Epoch 25/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3932 - accuracy: 0.8259
# Epoch 26/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3930 - accuracy: 0.8253
# Epoch 27/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3843 - accuracy: 0.8303
# Epoch 28/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3808 - accuracy: 0.8318
# Epoch 29/50
# 375/375 [==============================] - 33s 88ms/step - loss: 1.5415 - accuracy: 0.7986
# Epoch 30/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.4097 - accuracy: 0.8165
# Epoch 31/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3839 - accuracy: 0.8292
# Epoch 32/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3686 - accuracy: 0.8382
# Epoch 33/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3588 - accuracy: 0.8424
# Epoch 34/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3628 - accuracy: 0.8419
# Epoch 35/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3500 - accuracy: 0.8468
# Epoch 36/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3514 - accuracy: 0.8464
# Epoch 37/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3488 - accuracy: 0.8478
# Epoch 38/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3445 - accuracy: 0.8488
# Epoch 39/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3407 - accuracy: 0.8517
# Epoch 40/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3379 - accuracy: 0.8519
# Epoch 41/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3459 - accuracy: 0.8497
# Epoch 42/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3398 - accuracy: 0.8518
# Epoch 43/50
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3393 - accuracy: 0.8534
# Epoch 44/50
# 375/375 [==============================] - 33s 88ms/step - loss: 6.4003 - accuracy: 0.7889
# Epoch 45/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.4884 - accuracy: 0.7863
# Epoch 46/50
# 375/375 [==============================] - 34s 89ms/step - loss: 0.4388 - accuracy: 0.8071
# Epoch 47/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.4101 - accuracy: 0.8189
# Epoch 48/50
# 375/375 [==============================] - 34s 89ms/step - loss: 0.3896 - accuracy: 0.8274
# Epoch 49/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3773 - accuracy: 0.8338
# Epoch 50/50
# 375/375 [==============================] - 33s 89ms/step - loss: 0.3632 - accuracy: 0.8392

# %%
model.evaluate([X_test_indices, X_meta_test], y_test)
# Out:
# 750/750 [==============================] - 23s 30ms/step - loss: 0.4499 - accuracy: 0.8055
# [0.44989725947380066, 0.8054583072662354]

# %%
model.predict([X_test_indices, X_meta_test])
# Out:
# array([[0.27726993],
#        [0.11961023],
#        [0.04404958],
#        ...,
#        [0.76257765],
#        [0.4046005 ],
#        [0.97232705]], dtype=float32)
